# %%
import numpy as np
import pandas as pd
dict1= {
    "name":['harry','rohan','skillf','shubh'],
    "marks":[34,78,56,29],
    "city":['Delhi', 'Pune', 'Alwar', 'Noida']
}
print(dict1)

df=pd.DataFrame(dict1)

print(df)
print(df.head(2)) 
print(df.tail(2)) 

df.to_csv('friends.csv', index=False)

print(df.describe())

# %%
example=pd.read_csv('example.csv')
print(example)

# %%
ser=pd.Series(np.random.rand(11),index=np.arange(11))
print(ser)
print(type(ser))

# %%
df1=pd.DataFrame(np.random.rand(30,5), index=np.arange(1,31))
print(df1)

t1=type(df1)
print(t1)

# %%
df1.describe()

# %%
df1.dtypes

#df1[0][0]="name"
#df1.dtypes

# %%
df1.T
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 df1.t
#
# File c:\Users\Shivam Anand\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:6206, in NDFrame.__getattr__(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 't'
