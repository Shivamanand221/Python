# %%
import numpy as np
import pandas as pd

# %%
pd.__version__
# Out:
# '3.0.3'

# %%
df=pd.DataFrame([11,22,33])
print(df)
df1=pd.DataFrame([11,22,33], columns=['columns'])
print(df1)
# Out:
#     0
# 0  11
# 1  22
# 2  33
#    columns
# 0       11
# 1       22
# 2       33

# %%
print(type(df))
# Out:
# <class 'pandas.DataFrame'>

# %%
data = {
    'Name': ['rohan', 'amit', 'suhani', 'lalita'],
    'age': [21,31,23,45],
    'Salary': [20000,34000, 25000,30000]
}
print(type(data))
# Out:
# <class 'dict'>

# %%
df=pd.DataFrame(data)
print(type(df))
print(df)
# Out:
# <class 'pandas.DataFrame'>
#      Name  age  Salary
# 0   rohan   21   20000
# 1    amit   31   34000
# 2  suhani   23   25000
# 3  lalita   45   30000

# %%
print(df.head(2))
print(df.tail(2))
print(df.shape)
print(df.columns)
# Out:
#     Name  age  Salary
# 0  rohan   21   20000
# 1   amit   31   34000
#      Name  age  Salary
# 2  suhani   23   25000
# 3  lalita   45   30000
# (4, 3)
# Index(['Name', 'age', 'Salary'], dtype='str')

# %%
df.rename(columns={'Salary': 'income'},inplace=True)
print(df)
dfr=df.rename(columns={'Salary': 'income'})
print(dfr)
# Out:
#      Name  age  income
# 0   rohan   21   20000
# 1    amit   31   34000
# 2  suhani   23   25000
# 3  lalita   45   30000
#      Name  age  income
# 0   rohan   21   20000
# 1    amit   31   34000
# 2  suhani   23   25000
# 3  lalita   45   30000

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    4 non-null      str
#  1   age     4 non-null      int64
#  2   income  4 non-null      int64
# dtypes: int64(2), str(1)
# memory usage: 228.0 bytes
#              age        income
# count   4.000000      4.000000
# mean   30.000000  27250.000000
# std    10.893423   6075.908711
# min    21.000000  20000.000000
# 25%    22.500000  23750.000000
# 50%    27.000000  27500.000000
# 75%    34.500000  31000.000000
# max    45.000000  34000.000000

# %%
df.to_csv('data.csv', index=False)

# %%
read=pd.read_csv('data.csv')
print(read)
# Out:
#      Name  age  income
# 0   rohan   21   20000
# 1    amit   31   34000
# 2  suhani   23   25000
# 3  lalita   45   30000

# %%
df[['Name','income']]
# Out:
#      Name  income
# 0   rohan   20000
# 1    amit   34000
# 2  suhani   25000
# 3  lalita   30000

# %%
print(df.loc[df.Name=='rohan'])
print(df.loc[(df.Name=='rohan') & (df.income>=20000)])
print(df.loc[0:2])
# Out:
#     Name  age  income
# 0  rohan   21   20000
#     Name  age  income
# 0  rohan   21   20000
#      Name  age  income
# 0   rohan   21   20000
# 1    amit   31   34000
# 2  suhani   23   25000

# %%
print(df.iloc[1])
print(df.iloc[0:2])
print(df.iloc[0:4:2])
# Out:
# Name       amit
# age          31
# income    34000
# Name: 1, dtype: object
#     Name  age  income
# 0  rohan   21   20000
# 1   amit   31   34000
#      Name  age  income
# 0   rohan   21   20000
# 2  suhani   23   25000

# %%
print(df[(df['age']>25)])
print(df[(df['age']>25) & (df['income']>=32000)])
# Out:
#      Name  age  income
# 1    amit   31   34000
# 3  lalita   45   30000
#    Name  age  income
# 1  amit   31   34000

# %%
df.where(df['age']>25)
# Out:
#      Name   age   income
# 0     NaN   NaN      NaN
# 1    amit  31.0  34000.0
# 2     NaN   NaN      NaN
# 3  lalita  45.0  30000.0

# %%
df.where(df['age']>25, other= 'Not Eligible')
# Out:
#            Name           age        income
# 0  Not Eligible  Not Eligible  Not Eligible
# 1          amit            31         34000
# 2  Not Eligible  Not Eligible  Not Eligible
# 3        lalita            45         30000

# %%
df['bonus']=df['income']*0.2
df
# Out:
#      Name  age  income   bonus
# 0   rohan   21   20000  4000.0
# 1    amit   31   34000  6800.0
# 2  suhani   23   25000  5000.0
# 3  lalita   45   30000  6000.0

# %% [markdown]
# Rows & Columns modification

# %%
df.loc[0, 'income']=35000
df
df.loc[df.Name== 'rohan', 'income']=34500
df
df.loc[df.Name== 'amit', 'income']=34500
df
# Out:
#      Name  age  income   bonus
# 0   rohan   21   34500  4000.0
# 1    amit   31   34500  6800.0
# 2  suhani   23   25000  5000.0
# 3  lalita   45   30000  6000.0

# %%
#df=df.drop(df[df.Name=='gian'].index)
#df.drop('amit', axis=1, inplace=True)
df
# Out:
#      Name  age  income   bonus
# 0   rohan   21   34500  4000.0
# 1    amit   31   34500  6800.0
# 2  suhani   23   25000  5000.0
# 3  lalita   45   30000  6000.0

# %%
df.sort_values(by='age', inplace=True)
print(df)
df.sort_values(by='income', ascending=False, inplace=True)
df
# Out:
#      Name  age  income   bonus
# 0   rohan   21   34500  4000.0
# 2  suhani   23   25000  5000.0
# 1    amit   31   34500  6800.0
# 3  lalita   45   30000  6000.0
#      Name  age  income   bonus
# 0   rohan   21   34500  4000.0
# 1    amit   31   34500  6800.0
# 3  lalita   45   30000  6000.0
# 2  suhani   23   25000  5000.0

# %%
df[['Name','income']].sort_values(by='income', ascending=False)
# Out:
#      Name  income
# 0   rohan   34500
# 1    amit   34500
# 3  lalita   30000
# 2  suhani   25000

# %%
df['income'].dtype
# Out:
# dtype('int64')

# %%
df.isnull()
# Out:
#     Name    age  income  bonus
# 0  False  False   False  False
# 1  False  False   False  False
# 3  False  False   False  False
# 2  False  False   False  False

# %%
df.loc[df.Name=='rohan', 'Salary']= np.nan
df.drop('Salary', axis=1, inplace=True)
df
# Out:
#      Name  age  income   bonus
# 0   rohan   21   34500  4000.0
# 1    amit   31   34500  6800.0
# 3  lalita   45   30000  6000.0
# 2  suhani   23   25000  5000.0

# %%
df.loc[df.Name=='rohan', 'income']= np.nan
print(df.isnull())
df.isnull().sum()
# Out:
#     Name    age  income  bonus
# 0  False  False    True  False
# 1  False  False   False  False
# 3  False  False   False  False
# 2  False  False   False  False
# Name      0
# age       0
# income    1
# bonus     0
# dtype: int64

# %%
df.fillna(0, inplace=True)
df
# Out:
#      Name  age   income   bonus
# 0   rohan   21      0.0  4000.0
# 1    amit   31  34500.0  6800.0
# 3  lalita   45  30000.0  6000.0
# 2  suhani   23  25000.0  5000.0

# %%
df['Month']=[1,1,3,3]
df
# Out:
#      Name  age   income   bonus  Month
# 0   rohan   21      0.0  4000.0      1
# 1    amit   31  34500.0  6800.0      1
# 3  lalita   45  30000.0  6000.0      3
# 2  suhani   23  25000.0  5000.0      3

# %%
print(df['Month'].value_counts())
print(df['income'].value_counts())
df.loc[df.Name=='rohan', 'income']=34000
df
# Out:
# Month
# 1    2
# 3    2
# Name: count, dtype: int64
# income
# 0.0        1
# 34500.0    1
# 30000.0    1
# 25000.0    1
# Name: count, dtype: int64
#      Name  age   income   bonus  Month
# 0   rohan   21  34000.0  4000.0      1
# 1    amit   31  34500.0  6800.0      1
# 3  lalita   45  30000.0  6000.0      3
# 2  suhani   23  25000.0  5000.0      3

# %%
df.groupby('Month')['income'].sum()
# Out:
# Month
# 1    68500.0
# 3    55000.0
# Name: income, dtype: float64

# %%
df.groupby('Month').agg({'income': 'mean', 'Name':'count'})
# Out:
#         income  Name
# Month
# 1      34250.0     2
# 3      27500.0     2

# %%
df3 = pd.DataFrame({'ID': [1,2,3], 'Name':['A', 'B', 'C']})
df4 = pd.DataFrame({'ID': [1,2,2,4], 'Score': [88, 96, 77, 79]})
print(df3)
print(df4)
# Out:
#    ID Name
# 0   1    A
# 1   2    B
# 2   3    C
#    ID  Score
# 0   1     88
# 1   2     96
# 2   2     77
# 3   4     79

# %%
pd.concat([df3, df4], axis=0)
# Out:
#    ID Name  Score
# 0   1    A    NaN
# 1   2    B    NaN
# 2   3    C    NaN
# 0   1  NaN   88.0
# 1   2  NaN   96.0
# 2   2  NaN   77.0
# 3   4  NaN   79.0

# %%
pd.concat([df3, df4], axis=1)
# Out:
#     ID Name  ID  Score
# 0  1.0    A   1     88
# 1  2.0    B   2     96
# 2  3.0    C   2     77
# 3  NaN  NaN   4     79

# %%
print(pd.merge(df3, df4, how='inner', on='ID'))
print(pd.merge(df3, df4, how='right', on='ID'))
print(pd.merge(df3, df4, how='left', on='ID'))
# Out:
#    ID Name  Score
# 0   1    A     88
# 1   2    B     96
# 2   2    B     77
#    ID Name  Score
# 0   1    A     88
# 1   2    B     96
# 2   2    B     77
# 3   4  NaN     79
#    ID Name  Score
# 0   1    A   88.0
# 1   2    B   96.0
# 2   2    B   77.0
# 3   3    C    NaN

# %%
print(pd.merge(df3, df4, how='inner', left_on='ID', right_on='ID'))
# Out:
#    ID Name  Score
# 0   1    A     88
# 1   2    B     96
# 2   2    B     77
