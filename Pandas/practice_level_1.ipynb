# %%
import numpy as np
import pandas as pd

# %%
#Question 1: Create a DataFrame

data={
    "Name": ["Aman", "Riya", "Karan"],
    "Age": [21, 22, 20]
}
df=pd.DataFrame(data)
df

# %%
#Question 2: Select a Column

import pandas as pd

df1 = pd.DataFrame({
    "Name": ["Aman", "Riya", "Karan"],
    "Age": [21, 22, 20]
})

df1['Age']

# %%
#Question 3: Read Basic Information
print(df.head(2))
print(df.columns)
print(df.shape)
# Out:
#    Name  Age
# 0  Aman   21
# 1  Riya   22
# Index(['Name', 'Age'], dtype='str')
# (3, 2)
