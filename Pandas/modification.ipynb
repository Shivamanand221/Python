# %%
import pandas as pd

# %%
data= [
    ["ayush", 22, 85, "delhi"],
    ["rahul", 24, 91, "Mumbai"],
    ["aman", 21, 78, "Jaipur"],
    ["rohit", 23, 88, "Delhi"],
    ["neha", 25, 95, "Mumbai"]
]

df= pd.DataFrame(
    data,
    columns=["name", "age", "marks", "city"]
)

print(df)

df["passed"]= True

print(df)  

df["grade"]= ["B", "A", "C", "B", "A"]

print(df)
# Out:
#     name  age  marks    city
# 0  ayush   22     85   delhi
# 1  rahul   24     91  Mumbai
# 2   aman   21     78  Jaipur
# 3  rohit   23     88   Delhi
# 4   neha   25     95  Mumbai
#     name  age  marks    city  passed
# 0  ayush   22     85   delhi    True
# 1  rahul   24     91  Mumbai    True
# 2   aman   21     78  Jaipur    True
# 3  rohit   23     88   Delhi    True
# 4   neha   25     95  Mumbai    True
#     name  age  marks    city  passed grade
# 0  ayush   22     85   delhi    True     B
# 1  rahul   24     91  Mumbai    True     A
# 2   aman   21     78  Jaipur    True     C
# 3  rohit   23     88   Delhi    True     B
# 4   neha   25     95  Mumbai    True     A

# %%
df["age_after_5"]= df["age"]+5
print(df)
# Out:
#     name  age  marks    city  passed grade  age_after_5
# 0  ayush   22     85   delhi    True     B           27
# 1  rahul   24     91  Mumbai    True     A           29
# 2   aman   21     78  Jaipur    True     C           26
# 3  rohit   23     88   Delhi    True     B           28
# 4   neha   25     95  Mumbai    True     A           30

# %%
df["percentage"]= df["marks"]/100 * 100

df["passed"]= df["marks"]>=80

print(df)
# Out:
#     name  age  marks    city  passed grade  age_after_5  percentage
# 0  ayush   22     85   delhi    True     B           27        85.0
# 1  rahul   24     91  Mumbai    True     A           29        91.0
# 2   aman   21     78  Jaipur   False     C           26        78.0
# 3  rohit   23     88   Delhi    True     B           28        88.0
# 4   neha   25     95  Mumbai    True     A           30        95.0
