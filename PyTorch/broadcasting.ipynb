# %%
import torch

# %%
import torch

x = torch.tensor([10, 20, 30])
y = torch.tensor([1])

print(x + y)
# Out:
# tensor([11, 21, 31])

# %%
x = torch.tensor([
    [1, 2, 3],
    [4, 5, 6]
])

y = torch.tensor([10, 20, 30])

print(x + y)
# Out:
# tensor([[11, 22, 33],
#         [14, 25, 36]])
