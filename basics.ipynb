# %%
name = "amit"
age = 22
salary = 50000

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
a=input("Enter age")

# %%
print(a)
print(type(a))
# Out:
# 27
# <class 'str'>

# %%
marks=int(input())

if marks >= 90:
    print("Grade A")
elif marks >= 75:
    print("Grade B")
elif marks >= 60:
    print("Grade C")
else:
    print("Fail")
# Out:
# Grade B

# %%
age = 20
citizen = True

if age >= 18:
    if citizen:
        print("Eligible to vote")
# Out:
# Eligible to vote

# %%
if age>18 & age<60:
    print("vote")
# Out:
# vote

# %%
numbers=[100,101,102,103,104,105]
numbers.append(106)
numbers.insert(7,109)
numbers.extend([100,200])
numbers.remove(109)
numbers.pop()
print(numbers)
numbers.clear()
print(numbers)
# Out:
# [100, 101, 102, 103, 104, 105, 106, 100]
# []

# %%
marks=(11,12,13,14,15,12,13,12)
print(marks)
print(marks[2])
#marks[1]=15  cant modify
print(marks.count(12))
print(marks.index(12))
# Out:
# (11, 12, 13, 14, 15, 12, 13, 12)
# 13
# 3
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 6
#       2 print(marks)
#       3 print(marks[2])
#       4 #marks[1]=15  cant modify
#       5 print(marks.count(12))
# ----> 6 print(marks.index(19))
#
# ValueError: tuple.index(x): x not in tuple
