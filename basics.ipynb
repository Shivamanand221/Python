# %%
import os

# %%
name = "amit"
age = 27
salary = 50000

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
a=input("Enter age")

# %%
print(a)
print(type(a))
# Out:
# 21
# <class 'str'>

# %%
marks=int(input())

if marks >= 90:
    print("Grade A")
elif marks >= 75:
    print("Grade B")
elif marks >= 60:
    print("Grade C")
else:
    print("Fail")
# Out:
# Fail

# %%
age = 20
citizen = True

if age >= 18:
    if citizen:
        print("Eligible to vote")
# Out:
# Eligible to vote

# %%
if age>18 & age<60:
    print("vote")
# Out:
# vote

# %%
numbers=[100,101,102,103,104,105]

numbers.append(106)
numbers.insert(7,109)
numbers.extend([100,200])
numbers.remove(109)
numbers.pop()

print(numbers)

numbers.clear()
print(numbers)
# Out:
# [100, 101, 102, 103, 104, 105, 106, 100]
# []

# %%
marks=(11,12,13,14,15,12,13,12)

print(marks)
print(marks[2])

#marks[1]=15  cant modify

print(marks.count(12))
print(marks.index(12))
# Out:
# (11, 12, 13, 14, 15, 12, 13, 12)
# 13
# 3
# 1

# %%
nums={1,2,3,4,5,6,2,3,2}
print(nums)

nums.add(10)
print(nums)

nums.remove(3)
print(nums)

nums.discard(3)
print(nums)
# Out:
# {1, 2, 3, 4, 5, 6}
# {1, 2, 3, 4, 5, 6, 10}
# {1, 2, 4, 5, 6, 10}
# {1, 2, 4, 5, 6, 10}

# %%
student = {
    "name":"amit",
    "age":27,
    "city":"Delhi"
}
print(student)
print(student["name"])

student["college"]="DU"
print(student)

student.keys()
student.values()
student.items()
student.get("name")

#print(student["salary"]) show error
print(student.get("salary"))
# Out:
# {'name': 'amit', 'age': 27, 'city': 'Delhi'}
# amit
# {'name': 'amit', 'age': 27, 'city': 'Delhi', 'college': 'DU'}
# None

# %%
def greet():
    print("Hello")

greet()
# Out:
# Hello

# %%
def greet(name):
    print("Hello", name)

greet("aman")
greet("naman")
# Out:
# Hello aman
# Hello naman

# %%
def add(a,b):
    print(a+b)

add(20,30)
# Out:
# 50

# %%
def add(a,b):
    return a+b

result=add(23,34)
print(result)

x= add(5,10)
print(x*2)
# Out:
# 57
# 30

# %%
def greet(name="aman"):
    return name

result1=greet()
result2=greet("naman")

print("Hello", result1)
print("Hello", result2)
# Out:
# Hello aman
# Hello naman

# %%
def student(name="aman", age=20, gender="Male"):
    return name, age, gender

print("Details", student())
print("Details", student("Naman"))
print("Details", student("Naman",34))
print("Details", student("Naman",34, "Male"))
# Out:
# Details ('aman', 20, 'Male')
# Details ('Naman', 20, 'Male')
# Details ('Naman', 34, 'Male')
# Details ('Naman', 34, 'Male')

# %%
def total(*numbers):
    print(numbers)

total()
total(10)
total(10,20,30)
# Out:
# ()
# (10,)
# (10, 20, 30)

# %%
def details(**data):
    print(data)

details()
details(name="aman")
details(age=35, name="aman", gender="M")
# Out:
# {}
# {'name': 'aman'}
# {'age': 35, 'name': 'aman', 'gender': 'M'}

# %%
square= lambda x: x*x
print(square(5))
# Out:
# 25

# %%
add =lambda a,b: a+b
print(add(3,4))
# Out:
# 7

# %%
x=100
def test():
    print(x)

test()

def test():
    y=50
    print(y)

test()
# Out:
# 100
# 50

# %%
a = 10
b = 0

try:
    print(10 / 0)
except:
    print("Cannot devide by zero")
# Out:
# Cannot devide by zero

# %%
try:
    x = 10 / 0
except:
    print("Error")
else:
    print("Success")
# Out:
# Error

# %%
try:
    file=open("data.txt")
except FileNotFoundError:
    print("File not found")
finally:
    print("Finished")
# Out:
# File not found
# Finished

# %%
def hello():
    print("hello")
    hello()

#hello()

# %%
for i in range(5,0,-1):
    print(i)
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
def countdown(n):
    if n==0:
        return
    print(n)
    countdown(n-1)

countdown(5)
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
def factorial(n):
    if n==1:
        return 1
    
    return n*factorial(n-1)

factorial(5)
# Out:
# 120

# %%
def sum(n):
    if n==0:
        return 0
    
    return n+sum(n-1)

sum(10)
# Out:
# 55

# %%
file= open("notes.txt", "r")
print(file.read())
file.close()
# Out:
# Learning Python
# FastAPI

# %%
file= open("notes.txt")

for line in file:
    print(line)

file.close()
# Out:
# Learning Python
#
# FastAPI

# %%
file= open("notes.txt", "w")
file.write("Learning Python")
file.close()

file_update=open("notes.txt", "r")
print(file_update.read())
# Out:
# Learning Python

# %%
file = open("notes.txt", "a")
file.write("\nFastAPI")
file.close()

# %%
file = open("notes.txt")
print(file.read())
file.close()
# Out:
# Learning Python
# FastAPI

# %%
with open("notes.txt") as file:
    print(file.read())

file.close()
# Out:
# Learning Python
# FastAPI

# %%
print(os.path.exists("notes.txt"))
# Out:
# True

# %%
with open("notes.txt") as f:
    
    #print(f.read())
    print(f.tell())
    print(f.read(5))
    print(f.tell())
    print(f.seek(0))
    print(f.tell())
# Out:
# 0
# Learn
# 5
# 0
# 0

# %%
try:
    with open("abc.txt") as file:
        print(file.read())
except FileNotFoundError:
    print("File not found")
# Out:
# File not found

# %%
class Student:
    pass

s1=Student()
s2=Student()

print(s1, s2)
# Out:
# <__main__.Student object at 0x000001CCAF7F9BE0> <__main__.Student object at 0x000001CCAF544690>

# %%
class student:
    def __init__(self):
        print(self)
    
s1=student()
# Out:
# <__main__.student object at 0x000001CCAF7F97F0>

# %%
class student():
    def __init__(self,name):
        print(self, name)

s1=student("aman")
# Out:
# <__main__.student object at 0x000001CCAF7F9BE0> aman

# %%
class student():
    def __init__(self, name, age):
        print(self)
        self.name=name
        self.age=age

s1= student("aman", 21)
s2= student("naman", 20)
print(s1.name, s1.age)
# Out:
# <__main__.student object at 0x000001CCAF7F97F0>
# <__main__.student object at 0x000001CCAF544B90>
# aman 21

# %%
class student():
    def __init__(self, name, age):
        print(self)
        self.name=name
        self.age=age
    
    def introduce(self):
        print("Hii I am", self.name)

s1= student("aman", 21)
s2= student("naman", 20)
print(s1.name, s1.age)
s1.introduce()
# Out:
# <__main__.student object at 0x000001CCAF1A7620>
# <__main__.student object at 0x000001CCAF544690>
# aman 21
# Hii I am aman

# %%
class car():
    def __init__(self, company):
        self.company=company
        print(company)

car1= car("BMW")
car2= car("Audi")
# Out:
# BMW
# Audi

# %%
class animal:
    def eat(self):
        print("eating")
    
    def sleep(self):
        print("sleeping")
    
class dog(animal):
    def bark(self):
        print("barking")

dog1=dog()
dog1.bark()
dog1.eat()
dog1.sleep()
# Out:
# barking
# eating
# sleeping

# %%
class animal:
    def eat(self):
        print("eating")
    
    def sleep(self):
        print("sleeping")
    
class dog(animal):
    def bark(self):
        print("barking")

dog1=dog()
dog1.bark()
dog1.eat()
dog1.sleep()

class newdog(dog):
    def run(self):
        print("run")

dog2=newdog()
dog2.run()
dog2.bark()
dog2.eat()
dog2.sleep()
# Out:
# barking
# eating
# sleeping
# run
# barking
# eating
# sleeping

# %%
#Method Overriding

class animal:
    def sound(self):
        print("Animal sound")

class dog(animal):
    def sound(self):
        print("Bark")

dog1=dog()
dog1.sound()

dog2=animal()
dog2.sound()
# Out:
# Bark
# Animal sound

# %%
class Animal:

    def sound(self):
        print("Animal Sound")


class Dog(Animal):

    def sound(self):
        super().sound()
        print("Bark")

dog = Dog()
dog.sound()
# Out:
# Animal Sound
# Bark

# %%
class animal():

    def __init__(self):
        print("animal created")

class dog(animal):
    def __init__(self):
        super().__init__()
        print("dog created")

dog1=dog()
# Out:
# animal created
# dog created

# %%
class animal:
    def __init__(self, name):
        self.name=name

class dog(animal):
    def __init__(self, name, breed):
        super().__init__(name)
        self.breed= breed

dog=dog("tom", "labrador")
print(dog.name)
print(dog.breed)
# Out:
# tom
# labrador

# %%
#Multiple Inheritance
class camara:
    def click(self):
        print("photo")

class phone:
    def call(self):
        print("calling")

class smartphone(camara, phone):
    pass

phone1= smartphone()
phone1.call()
phone1.click()
# Out:
# calling
# photo

# %%
#Hierarchical Inheritance
class Animal:
    pass


class Dog(Animal):
    pass


class Cat(Animal):
    pass

# %%
class bankaccount:
    
    def  __init__(self, balance):
        self.balance=balance

acc=bankaccount(1000)
print(acc.balance)
acc.balance=-2000
print(acc.balance)
# Out:
# 1000
# -2000

# %%
class bankaccount:
    
    def  __init__(self, balance):
        self._balance=1000

acc=bankaccount(2000)
print(acc._balance)
# Out:
# 1000

# %%
class BankAccount:

    def __init__(self):
        self.__balance = 1000
        print(self.__balance)
acc=bankaccount(2000)
#print(acc.__balance) will show error

# %%
class bankaccount:
    def __init__(self):
        self.__balance=1000

    def get_balance(self):
        return self.__balance

acc=bankaccount()
print(acc.get_balance())
# Out:
# 1000

# %%
class bankaccount:
    def __init__(self):
        self.__balance=1000

    def set_balance(self, amount):
        if amount>=0:
            self.__balance=amount

acc=bankaccount()

# %%
class dog:
    def sound(self):
        print("Bark")

class cat:
    def sound(self):
        print("meow")

dog1=dog()
dog1.sound()
cat1=cat()
cat1.sound()

animals=[dog(), cat()]

for animal in animals:
    animal.sound()
# Out:
# Bark
# meow
# Bark
# meow

# %%
class person():
    def __init__(self, n, o):
        self.name=n
        self.occ=o
        print(f"{self.name} is {self.occ}")
        
    def info(self):
        print(f"{self.name} is {self.occ}")

a= person("Ayush", "Dev")
#a.name="Divya"
#a.occ="HR"
#print(a.name)
#a.info()
b= person("Divya", "HR")

a.info()
b.info()
# Out:
# Ayush is Dev
# Divya is HR
# Ayush is Dev
# Divya is HR

# %%
marks = [3,4,5, "Hello", True]

print(marks)
print(marks[0])
print(marks[-1])
print(len(marks))
print(marks[:])
print(marks[2:5])
print(marks[1:-1])
print(marks[5:1])
print(marks[0:5:2])

lst=[i for i in range(10,20,2)]
print(lst)
# Out:
# [3, 4, 5, 'Hello', True]
# 3
# True
# 5
# [3, 4, 5, 'Hello', True]
# [5, 'Hello', True]
# [4, 5, 'Hello']
# []
# [3, 5, True]
# [10, 12, 14, 16, 18]

# %%
tuple1= (1,2,(3,4,5),"Hello", True)

print(tuple1)
print(tuple1[0])
print(tuple1[-3])
print(len(tuple1))
print(tuple1[:])
print(tuple1[2:5])

tuple2= (i for i in range(10,20,2))
tuple3= (21,22,23,24,25)

print(tuple2)
print(list(tuple2))
print(tuple1+tuple3)

res=tuple1*3
print(res)

res2=tuple1.index("Hello")
print(res2)

res3=tuple1.index(2,0,5)
print(res3)
# Out:
# (1, 2, (3, 4, 5), 'Hello', True)
# 1
# (3, 4, 5)
# 5
# (1, 2, (3, 4, 5), 'Hello', True)
# ((3, 4, 5), 'Hello', True)
# <generator object <genexpr> at 0x0000013140ABE200>
# [10, 12, 14, 16, 18]
# (1, 2, (3, 4, 5), 'Hello', True, 21, 22, 23, 24, 25)
# (1, 2, (3, 4, 5), 'Hello', True, 1, 2, (3, 4, 5), 'Hello', True, 1, 2, (3, 4, 5), 'Hello', True)
# 3
# 1
